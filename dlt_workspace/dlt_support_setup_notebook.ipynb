# %%
# %sql
--volume of source files
create volume if not exists dev.bronze.landing;

# %%
#dbutils.fs.mkdirs("/Volumes/dev/bronze/landing/files")
dbutils.fs.mkdirs("/Volumes/dev/bronze/landing/autoloader/schemas")

# %%
# %sql
select * from dev.bronze.orders_raw limit 2
