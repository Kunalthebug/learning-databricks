# %% [markdown]
# ### This is the Biggest header

# %%
# %sh 
ls -l
echo "ABC"

# %%
# %sql
create volume if not exists workspace.default.volumewe47_datalake;

# %%
# %fs ls "/Volumes/workspace/default/volumewe47_datalake"

# %%
# %fs head "/Volumes/workspace/default/volumewe47_datalake/patients.csv"

# %%
dbutils.fs.rm('/Volumes/workspace/default/volumewe47_datalake/patients.csv')

# %%
# %sql
create table if not exists default.city (id int,city string);
insert into default.city values(1,'Kolkata'),(2,'Hyderabad');
select * from default.city;
delete from default.city;
drop table if exists default.city;

# %%
# %sh df -h

# %%
print(spark)

# %%
from pyspark.sql.session import SparkSession
spark1 = SparkSession.builder.getOrCreate()
display(spark1)
