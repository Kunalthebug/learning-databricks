# %%
# %sql
--Once for all activity
CREATE CONNECTION gcp_mysql_conn_wd36
TYPE mysql
OPTIONS (
  host 'host',
  port '3306',
  user 'devuser',
  password 'Inceptez@123'
);

# %%
# %sql
--Activity to create a foreign catalog to refresh/refer the metadata
CREATE FOREIGN CATALOG gcp_mysql_fc_wd36
USING CONNECTION gcp_mysql_conn_wd36;

# %%
# %sql
DESCRIBE CONNECTION gcp_mysql_conn_wd36;

# %%
# %sql
show catalogs;

# %%
# %sql
select * from gcp_mysql_fc_wd36.logistics.shipments1;

# %%
# %sql
--Historical (Onetime) load (Depends on the business requirement)
--If my project requires entire 3 years shipment data from external database  or if we need only one year, apply filters accordingly..
CREATE TABLE IF NOT EXISTS logistics_catalog_assign.default.shipments_databricks
USING DELTA
AS SELECT
  shipment_id,
  first_name,
  last_name,
  age,
  role,
  updated_at
FROM gcp_mysql_fc_wd36.logistics.shipments1;
